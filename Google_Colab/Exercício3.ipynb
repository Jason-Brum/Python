# %%
numero = 6/7
print ('Resultado: %f' % numero)
print ('Resultado: %.2f' % numero)
print ('Resultado: %8.2f' %numero)
print('Resultado: %d' % numero)
print('Resultado: %s' % numero)
# Out:
# Resultado: 0.857143
# Resultado: 0.86
# Resultado:     0.86
# Resultado: 0
# Resultado: 0.8571428571428571
